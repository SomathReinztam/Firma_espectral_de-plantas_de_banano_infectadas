# %%
from sklearn.ensemble import RandomForestRegressor
from plotRFrLearningCurve import plot_learningCurve
hyperparameters = {'n_estimators': 800, 'max_depth': 11, 'criterion': 'absolute_error', 'max_features': 'sqrt'}
reg = RandomForestRegressor(**hyperparameters)
plot_learningCurve(reg, random_state=12)

# %%
from sklearn.ensemble import RandomForestRegressor
from plotRFrFeatureSelection import plotFeatureSelection
hyperparameters = {'n_estimators': 800, 'max_depth': 11, 'criterion': 'absolute_error', 'max_features': 'sqrt'}
reg = RandomForestRegressor(**hyperparameters)
plotFeatureSelection(reg)
# Out:
# mean_absolute_error: 1.238
