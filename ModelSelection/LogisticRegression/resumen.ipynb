# %%
file = 'datos.csv'
path = r"C:\Users\Acer\Documents\python\Proyecto de investigacion ver2"
random_state = 12

# %%
from sklearn.linear_model import LogisticRegression
from plotLearningCurve import plot_learningCurve

# %%
hyperparameters = {'penalty': 'l2', 'C': 1, 'max_iter': 10000}
clf = LogisticRegression(**hyperparameters)

A = [file, path, random_state, clf]
plot_learningCurve(*A)

# %%
from sklearn.linear_model import LogisticRegression
from plotFeatureSelection import plot_logreg_features

# %%
hyperparameters = {'penalty': 'l1', 'C': 1, 'max_iter': 10000, 'solver':'liblinear'}
clf = LogisticRegression(**hyperparameters)

plot_logreg_features(clf)
# Out:
# score: 0.984
