# %%
from plotRFcLearningCurve import plot_learningCurve
from sklearn.ensemble import RandomForestClassifier

hyperparameters = {'n_estimators': 800, 'max_depth': 21, 'criterion': 'entropy', 'max_features': 'sqrt'}
clf = RandomForestClassifier(**hyperparameters)
plot_learningCurve(clf, random_state=12)

# %%
from sklearn.ensemble import RandomForestClassifier
from plotRFcFeatureSelection import plotFeatureSelection

hyperparameters = {'n_estimators': 800, 'max_depth': 21, 'criterion': 'entropy', 'max_features': 'sqrt'}
clf = RandomForestClassifier(**hyperparameters)
plotFeatureSelection(clf)
# Out:
# score: 1.0

# %%
from plotRFcLearningCurve import plot_learningCurve
from sklearn.ensemble import RandomForestClassifier

hyperparameters = {'n_estimators': 800, 'max_depth': 11, 'criterion': 'entropy', 'max_features': 'sqrt'}
clf = RandomForestClassifier(**hyperparameters)
plot_learningCurve(clf, random_state=12)

# %%
from sklearn.ensemble import RandomForestClassifier
from plotRFcFeatureSelection import plotFeatureSelection

hyperparameters = {'n_estimators': 800, 'max_depth': 11, 'criterion': 'entropy', 'max_features': 'sqrt'}
clf = RandomForestClassifier(**hyperparameters)
plotFeatureSelection(clf)
# Out:
# score: 1.0
