# %%
from sklearn.tree import DecisionTreeRegressor
from plotDTrFeatureSelection import plotFeatureSelection
hyperparameter = {'criterion':'absolute_error', 'max_depth':14}
reg = DecisionTreeRegressor(**hyperparameter)
plotFeatureSelection(reg)
# Out:
# mean_absolute_error: 0.178
