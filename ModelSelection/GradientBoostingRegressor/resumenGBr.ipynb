# %%
from sklearn.ensemble import GradientBoostingRegressor
from plotGBrLearningCurve import plot_learningCurve
hyperparameters = {'loss': 'absolute_error', 'n_estimators': 900, 'max_depth': 11, 'criterion': 'squared_error', 'max_features': 'sqrt'}
reg = GradientBoostingRegressor(**hyperparameters)
plot_learningCurve(reg, random_state=12)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from plotGBrFeatureSelection import plotFeatureSelection
hyperparameters = {'loss': 'absolute_error', 'n_estimators': 900, 'max_depth': 11, 'criterion': 'squared_error', 'max_features': 'sqrt'}
reg = GradientBoostingRegressor(**hyperparameters)
plotFeatureSelection(reg)
# Out:
# mean_absolute_error: 0.002
