# %%
from sklearn.ensemble import GradientBoostingClassifier
from plotGBcLearningCurve import plot_learningCurve

hyperparameter = {'loss': 'log_loss', 'n_estimators': 900, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 'sqrt'}
clf = GradientBoostingClassifier(**hyperparameter)
plot_learningCurve(clf, random_state=12)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from plotGBcFeatureSelection import plotFeatureSelection
hyperparameter = {'loss': 'log_loss', 'n_estimators': 900, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 'sqrt'}
clf = GradientBoostingClassifier(**hyperparameter)
plotFeatureSelection(clf)
# Out:
# score: 1.0
