# %%
from plotLearningCurve import plot_learningCurve
from sklearn.linear_model import LinearRegression

file = 'datos.csv'
path = r"C:\Users\Acer\Documents\python\Proyecto de investigacion ver2"
random_state = 12
clf = LinearRegression()

plot_learningCurve(file, path, random_state, clf)

# %%
from sklearn.linear_model import Lasso
from plotFeatureSelection import plot_lasso_features

hyperparameters = {'alpha':0.01, 'max_iter':5000}
reg = Lasso(**hyperparameters)


plot_lasso_features(reg)
# Out:
# mean_absolute_error: 0.805
# c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.867e+02, tolerance: 4.059e+00
#   model = cd_fast.enet_coordinate_descent(
