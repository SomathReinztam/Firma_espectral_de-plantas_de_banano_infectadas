# %%
from sklearn.tree import DecisionTreeClassifier
from plotDTcFeatureSelection import plotFeatureSelection
hyperparameter = {'criterion':'entropy', 'max_depth':14}
clf = DecisionTreeClassifier(**hyperparameter)
plotFeatureSelection(clf)
# Out:
# score: 1.0
