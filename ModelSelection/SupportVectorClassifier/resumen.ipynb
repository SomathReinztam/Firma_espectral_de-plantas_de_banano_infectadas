# %%
from sklearn.svm import SVC
from plotSVCLearningCurve import plot_learningCurve
random_state = 37
hyperparameters = {'C': 1, 'kernel': 'linear'}
clf = SVC(**hyperparameters)
plot_learningCurve(clf, random_state)
